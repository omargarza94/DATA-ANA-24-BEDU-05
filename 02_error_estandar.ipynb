# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **Estadsitica basic**

# %%
#Calcular la media de los costos
media_costos = np.mean(costos)
print(f'Media de los costos: {round(media_costos, 2)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b6ed80d0ead6> in <cell line: 2>()
#       1 #Calcular la media de los costos
# ----> 2 media_costos = np.mean(costos)
#       3 print(f'Media de los costos: {round(media_costos, 2)}')
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## Intereptacion estadistica

# %%
# Instalacion de dependecias para visualización
# !pip install matplotlib seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Confrigurar estilo de una grafica
sns.st(style='whitegrid')

# Crear histograma
plt.figure(figsize=(8, 6))
sns.histplot(costos, ked=True, color='skyblue', stat='density', bins=30)

# Agregar la media
plt.axvline(media_costos, color='red', linestyle='--', labl=f'Media $ {round(media_costos, 2)}')

# Error estabdar pintado
plt.axvline(media_costos - error_estandar, color='green',linestyle='--', lable=f'Media - Error Estandar$(round(media_costos - error_estandar, 2)}')


# Configurar nuestro grafico
plt.title('Distribucion de costos con media y error estandar')
plt.xlabel('Costo total')
plt.ylabel('Densidad')
plt.legend()

plt-show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-4582ce247110> in <cell line: 5>()
#       3
#       4 # Confrigurar estilo de una grafica
# ----> 5 sns.st(style='whitegrud')
#       6
#       7 # Crear histograma
#
# AttributeError: module 'seaborn' has no attribute 'st'

# %% [markdown]
# Intervalos de confianza

# %%
# Instalar scipy para uso estadsitico
# !pip install scipy
